# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris=load_iris()

X=pd.DataFrame(iris.data)
t=iris.target

# %%
#reduce 4 features into 2
X.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
sc=StandardScaler()
X_scaled=sc.fit_transform(X);

X_scaled.shape
# Out:
# (150, 4)

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=2)

Xpca=pca.fit_transform(X_scaled)

Xpca.shape
# Out:
# (150, 2)

# %%
print("Expalin variance ration", pca.explained_variance_ratio_)
# Out:
# Expalin variance ration [0.72962445 0.22850762]

# %%
print(pca.components
